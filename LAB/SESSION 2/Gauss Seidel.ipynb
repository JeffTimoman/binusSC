# %% [markdown]
# Gauss Seidel
# 6a + 3b + 2c = 15
# 2a + 7b + 3c = 6
# 7a + 5b + 15c= 12
# step 1
# problem ini diagonally ato enggak, cari nilai mutlak dulu
# misal 6 harus > |3|+|2|
# 7 > |2| + |3|
# 15 > |7| + |5|
#
# step 2
# a = (15-3b-2c)/6
# b = (6-2a-3c)/7
# c = (12-7a-5b)/15
#
# step 3 : iterasi
# Initial Value      I-1          I-2          I-3
# a           0       2.5            2.566
# b           0       0.142857       0.301
# c           0       -0.41428       -0.498
#
#
# Distance < Epsilon    Euclidian distance

# %%
import numpy as np

a = [[6, 3, 2],
     [2, 7, 3],
     [7, 5, 15]]

print(np.diag(a))
print(np.sum(np.abs(a), axis=1))

def checkDiagonallyDominant(a):
    diag = np.diag(a)
    sumWithDiag = np.sum(np.abs(a), axis=1)
    sumWithoutDiag = sumWithDiag - diag
    
    if np.all(diag > sumWithoutDiag):
        return True
    else:
        return False
        
checkDiagonallyDominant(a)
# Out:
# [ 6  7 15]
# [11 12 27]
# True

# %%
a = 0
b = 0
c = 0
epsilon = 0.1
limit = 15

oldValue = np.array([a, b, c])

for i in range(1, limit):
  a = (15-3*b-2*c)/6
  b = (6-2*a-3*c)/7
  c = (12-7*a-5*b)/15
  newValue = np.array([a, b, c])

  distance = np.sqrt(np.dot(newValue - oldValue, newValue-oldValue))

  if distance < epsilon:
    print("Solution found")
    isComplete = True
    break

  oldValue = newValue 

if isFinished == False:
  print("Solution Not Found")

# %%
CaseX = [
  [
    [-3,9,-6],
    [7,-2,-3],
    [4,1,-4]
  ],
  [
    [1, 3, -3, 9],
    [2, -9,3, -3],
    [-1, 3, 15, -1],
   [21, 4, -1, 10]
  ],
  [
    [4,2,-1],
    [1,3,-1],
    [5,2,10]
  ],
  [
    [-7,2,-4],
    [-1,-19,-13],
    [-3,3,-19]
  ],
  [
    [-12, 1, -4, 6],
    [-3, 8,-3, 2],
    [3, 3, 10, -3],
    [3, -2, 3, 12]
  ],
  [
    [2,1,-1],
    [-2,5,-3],
    [-1,-6,-9]
  ]
]
CaseY=[
   [0, -6, 5],
   [12, 9, -6, 11],
   [19, 12, 5],
   [8, 3, 5],
   [3, 6, 9, 21],
   [3, 9, 12]
]

# %%
def gauss_sediel(x, y, limit, epsilon):
    #diagonally dominant
    diag = np.diag(x)
    sumWithDiag = np.sum(np.abs(x), axis=1)
    sumWithoutDiag = sumWithDiag - diag
    
    if np.all(diag > sumWithoutDiag):
        return True
    else:
        return False
    
print(x.shape[0])
oldValue =  np.zeros(x.shape[0])

diagonal = np.diag(x)
x = -x
np.fill_diagonal(x,0)
print(x)
for i in range (1, limit):
    newValue= oldValue
    for j, row in enumerate(x):
        newValue[j] = (y[j] + np.dot(row, newValue))/diagonal

    distance = np.sqrt(np.dot(newValue - oldValue, newValue-oldValue))    

    if distance <= epsilon:
        return True
    oldValue = xNew
        
return False

# %%
import numpy as np

CaseX = [
  [
    [-3,9,-6],
    [7,-2,-3],
    [4,1,-4]
  ],
  [
    [1, 3, -3, 9],
    [2, -9,3, -3],
    [-1, 3, 15, -1],
   [21, 4, -1, 10]
  ],
  [
    [4,2,-1],
    [1,3,-1],
    [5,2,10]
  ],
  [
    [-7,2,-4],
    [-1,-19,-13],
    [-3,3,-19]
  ],
  [
    [-12, 1, -4, 6],
    [-3, 8,-3, 2],
    [3, 3, 10, -3],
    [3, -2, 3, 12]
  ],
  [
    [2,1,-1],
    [-2,5,-3],
    [-1,-6,-9]
  ]
]
CaseY=[
   [0, -6, 5],
   [12, 9, -6, 11],
   [19, 12, 5],
   [8, 3, 5],
   [3, 6, 9, 21],
   [3, 9, 12]
]

def gauss_sediel(x, y, limit, epsilon):
    #diagonally dominant
    diag = np.diag(x)
    sumWithDiag = np.sum(np.abs(x), axis=1)
    sumWithoutDiag = sumWithDiag - diag
    
    if np.all(diag > sumWithoutDiag):
        return True
    else:
        return False
    
    oldValue =  np.zeros(x.shape[0])
    diagonal = np.diag(x)
    x = -x
    np.fill_diagonal(x,0)

    for i in range (1, limit):
        newValue= oldValue
        for j, row in enumerate(x):
            newValue[j] = (y[j] + np.dot(row, newValue))/diagonal

        distance = np.sqrt(np.dot(newValue - oldValue, newValue-oldValue))    

        if distance <= epsilon:
            return True
        oldValue = newValue
        
    return False
